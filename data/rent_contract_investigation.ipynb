# %%
import pandas as pd

# %%
df = pd.read_csv("processing/rent_data.csv")
df.head()
# Out:
#   contract_start_date contract_end_date  contract_amount  \
# 0          2020-06-04        03-06-2021           130000
# 1          2020-07-21        20-07-2021            49052
# 2          2021-05-01        30-04-2022           500000
# 3          2020-02-23        22-02-2024          1549288
# 4          2020-01-01        31-12-2020            75000
#
#   ejari_property_type_en property_usage_en                  project_name_en  \
# 0                  Villa       Residential     Emirates Living - Springs 15
# 1                 Office        Commercial                   PLATINUM TOWER
# 2                   Flat       Residential                          THE 118
# 3                   Shop        Commercial  THE RESIDENCES AT MARINA GATE 1
# 4                   Flat       Residential                   CONCORDE TOWER
#
#    area_id        area_name_en
# 0    352.0  Al Thanayah Fourth
# 1    350.0    Al Thanyah Fifth
# 2    390.0        Burj Khalifa
# 3    330.0         Marsa Dubai
# ...
